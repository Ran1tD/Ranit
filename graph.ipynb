# %%
import numpy as np
import matplotlib.pyplot as plt
class Graph:
    def RandomArrayGraph():
        x_axis=np.random.randint(10,90,12)
        y_axis=np.random.randint(50,120,12)
        x_axis=np.array_split(x_axis,2)
        print(x_axis,type(y_axis),len(x_axis))
        print(y_axis,type(y_axis),len(y_axis))
Graph.RandomArrayGraph()

# %%
import numpy as np
import matplotlib.pyplot as plt
class Graph:
    def RandomArrayGraph():
        x_axis=np.random.randint(10,90,12)
        y_axis=np.random.randint(50,120,12)
        #x_axis=np.array_split(x_axis,2)
        #y_axis=np.array_split(y_axis,2)
        print(x_axis,type(y_axis),len(x_axis))
        print(y_axis,type(y_axis),len(y_axis))
        #plt.plot(x_axis,y_axis,marker=0,mfc="red",mec="red",color="blue")
        plt.plot(x_axis,marker=0,mfc="violet",mec="red",color="blue")
        plt.plot(y_axis,marker=0,mfc="violet",mec="red",color="black")
        plt.grid(color="orange")
        plt.xlabel("stocks")
        plt.ylabel("share price")
        plt.title("stock market")
        plt.show()
Graph.RandomArrayGraph()
# Out:
# [50 56 34 32 26 69 26 23 36 69 74 31] <class 'numpy.ndarray'> 12
# [110  67  64  89  98  83  71  98  90 109  64  97] <class 'numpy.ndarray'> 12
